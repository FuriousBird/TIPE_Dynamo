# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#use numpy to load the csv files
data1 = np.loadtxt('simple1.csv', delimiter=',', skiprows=1)
data2 = np.loadtxt('carac2.csv', delimiter=',', skiprows=1)

R = 10e3 #10kOhm

#plot the data
X1=data1[:,1]-data1[:,3]
plt.plot((X1)[X1>-2.1], data1[:,3][X1>-2.1], label='diode simple')
plt.plot(data2[:,1]-data2[:,3], data2[:,3], label='carac2')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid()
plt.legend()

# %% [markdown]
# ![Diode_zener.png](attachment:Diode_zener.png)
